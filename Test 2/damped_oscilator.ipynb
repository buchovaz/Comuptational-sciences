# %%
import numpy as np
import matplotlib.pyplot as plt
from math import e

# %%
m = 1
b = 0.5
k = 4
t = np.linspace(0,20,1000)
x = e**(-0.25*t)*np.cos(1.984*t)

# %%
fig, ax = plt.subplots() 
ax.plot(t,x, color = "purple")
ax.set_xlabel("Time")
ax.set_ylabel("Amplitude")
plt.show
plt.savefig("underdamped.png")
